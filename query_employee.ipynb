# %%
import adbc_driver_db2.dbapi as dbapi

uri = "DATABASE=testdb;UID=db2inst2;PWD=password;HOSTNAME=localhost;PORT=50000;PROTOCOL=TCPIP"

conn = dbapi.connect(uri)
cur = conn.cursor()

print("✅ Connected to DB2")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 5
#       1 import adbc_driver_db2.dbapi as dbapi
#       2
#       3 uri = "DATABASE=testdb;UID=db2inst2;PWD=password;HOSTNAME=localhost;PORT=50000;PROTOCOL=TCPIP"
#       4
# ----> 5 conn = dbapi.connect(uri)
#       6 cur = conn.cursor()
#       7
#       8 print("✅ Connected to DB2")
#
# File ~/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/dbapi.py:127, in connect(uri, db_kwargs, conn_kwargs, autocommit, **kwargs)
#     124 conn = None
#     126 try:
# --> 127     db = adbc_driver_db2.connect(uri, db_kwargs=db_kwargs)
#     128     conn = adbc_driver_manager.AdbcConnection(db, **(conn_kwargs or {}))
#     129     return adbc_driver_manager.dbapi.Connection(
#     130         db, conn, conn_kwargs=conn_kwargs, autocommit=autocommit, **kwargs
#     131     )
#
# File ~/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/__init__.py:74, in connect(uri, db_kwargs)
#      72 if db_kwargs:
#      73     kwargs.update(db_kwargs)
# ---> 74 return adbc_driver_manager.AdbcDatabase(**kwargs)
#
# File adbc_driver_manager/_lib.pyx:605, in adbc_driver_manager._lib.AdbcDatabase.__init__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# File adbc_driver_manager/_lib.pyx:262, in adbc_driver_manager._lib.check_error()
# --> 262 'Could not get source, probably due dynamically evaluated source code.'
#
# ProgrammingError: NOT_FOUND: [Driver Manager] Could not load `/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so`: dlopen() failed: dlopen(/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so, 0x0006): Library not loaded: libdb2.dylib
#   Referenced from: <2CE935EA-4392-394A-9906-3912134BC181> /Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so
#   Reason: tried: 'libdb2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibdb2.dylib' (no such file), 'libdb2.dylib' (no such file), '/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file), '/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file)
# dlopen() failed: dlopen(lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib, 0x0006): tried: 'lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/opt/homebrew/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/usr/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file, not in dyld cache), 'lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file)

# %%
import os

os.environ["DYLD_LIBRARY_PATH"] = "/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/.venv-db2/lib/python3.14/site-packages/clidriver/lib"

# Optional but helps on Mac
os.environ["DYLD_FALLBACK_LIBRARY_PATH"] = os.environ["DYLD_LIBRARY_PATH"]

print("✅ DB2 library path set")
# Out:
# ✅ DB2 library path set

# %%
import adbc_driver_db2.dbapi as dbapi

uri = "DATABASE=testdb;UID=db2inst2;PWD=password;HOSTNAME=localhost;PORT=50000;PROTOCOL=TCPIP"

conn = dbapi.connect(uri)
cur = conn.cursor()

print("✅ Connected to DB2")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 5
#       1 import adbc_driver_db2.dbapi as dbapi
#       2
#       3 uri = "DATABASE=testdb;UID=db2inst2;PWD=password;HOSTNAME=localhost;PORT=50000;PROTOCOL=TCPIP"
#       4
# ----> 5 conn = dbapi.connect(uri)
#       6 cur = conn.cursor()
#       7
#       8 print("✅ Connected to DB2")
#
# File ~/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/dbapi.py:127, in connect(uri, db_kwargs, conn_kwargs, autocommit, **kwargs)
#     124 conn = None
#     126 try:
# --> 127     db = adbc_driver_db2.connect(uri, db_kwargs=db_kwargs)
#     128     conn = adbc_driver_manager.AdbcConnection(db, **(conn_kwargs or {}))
#     129     return adbc_driver_manager.dbapi.Connection(
#     130         db, conn, conn_kwargs=conn_kwargs, autocommit=autocommit, **kwargs
#     131     )
#
# File ~/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/__init__.py:74, in connect(uri, db_kwargs)
#      72 if db_kwargs:
#      73     kwargs.update(db_kwargs)
# ---> 74 return adbc_driver_manager.AdbcDatabase(**kwargs)
#
# File adbc_driver_manager/_lib.pyx:605, in adbc_driver_manager._lib.AdbcDatabase.__init__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# File adbc_driver_manager/_lib.pyx:262, in adbc_driver_manager._lib.check_error()
# --> 262 'Could not get source, probably due dynamically evaluated source code.'
#
# ProgrammingError: NOT_FOUND: [Driver Manager] Could not load `/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so`: dlopen() failed: dlopen(/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so, 0x0006): Library not loaded: libdb2.dylib
#   Referenced from: <2CE935EA-4392-394A-9906-3912134BC181> /Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so
#   Reason: tried: 'libdb2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibdb2.dylib' (no such file), 'libdb2.dylib' (no such file), '/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file), '/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/libdb2.dylib' (no such file)
# dlopen() failed: dlopen(lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib, 0x0006): tried: 'lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/opt/homebrew/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file), '/usr/lib/lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file, not in dyld cache), 'lib/Users/nishantavasthi/Documents/arrow-adbc/arrow-adbc/python/adbc_driver_db2/adbc_driver_db2/libadbc_driver_db2.so.dylib' (no such file)
